# %% [markdown]
# <a href="https://colab.research.google.com/github/titirmajumderofficial-commits/my-first-repo/blob/main/Titir/my-first-repo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello GitHub!")
# Out:
# Hello GitHub!
